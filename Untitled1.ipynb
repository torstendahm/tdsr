# %%
# %load_ext autoreload
# %autoreload 2
from tdsm import TDSM, LCM, Traditional
from tdsm.plotting import plot
import matplotlib.pyplot as plt

# %%
# %time
tdsm = TDSM()
loading = FourPointsLoading(sc0=10)
config, t, cf, ratez, neqz = tdsm(loading=loading)
# Out:
#   File "/var/folders/r0/g076kbw90cs5scw1k46_049r0000gn/T/ipykernel_7350/3893366712.py", line 3
#     loading = 4PointsLoading()
#                ^
# SyntaxError: invalid syntax

# %%
plt.plot(cf)
plt.plot(ratez)
plt.plot(neqz)

# %%
plot(config, t, cf, ratez, neqz)
